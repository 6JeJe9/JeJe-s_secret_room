# %%
import pandas as pd
CA = pd.read_csv('C:/Users/user/Downloads/CAvideos.csv')
US = pd.read_csv('C:/Users/user/Downloads/USvideos.csv')

# %%
CA['country']="CA"
US['country']="US"

# %%
row_concat = pd.concat([CA, US])

# %%
row_concat
# Out:
#         video_id trending_date  \
# 0    n1WpP7iowLc      17.13.11
# 1    2Vv-BfVoq4g      17.13.11
# 2    d380meD0W0M      17.13.11
# 3    5qpjK5DgCt4      17.13.11
# 4    H1KBHFXm2Bg      17.13.11
# 5    JzCsM1vtn78      17.13.11
# 6    7MxiQ4v0EnE      17.13.11
# 7    0yIWz1XEeyc      17.13.11
# 8    FyZMnhUtLfE      17.13.11
# 9    AS9-ITLhQxo      17.13.11
# 10   43sm-QwLcx4      17.13.11
# 11   U3xLOo-CNwo      17.13.11
# 12   LUzsOyWp9lw      17.13.11
# 13   8NHA23f7LvU      17.13.11
# 14   gifPYwArCVQ      17.13.11
# 15   nc99ccSXST0      17.13.11
# 16   eAyxMv4IBH8      17.13.11
# 17   _uM5kFfkhB8      17.13.11
# 18   6H3wVsceoS0      17.13.11
# 19   ohACdnWapcY      17.13.11
# 20   PRlmRnU9qts      17.13.11
# 21   V4Uuxg6jmbo      17.13.11
# 22   kzwfHumJyYc      17.13.11
# 23   JwboxqDylgg      17.13.11
# 24   7779JdxVAg0      17.13.11
# 25   wuf2KinLxZ8      17.13.11
# 26   WuTFI5qftCE      17.13.11
# 27   exMNBvwCfRY      17.13.11
# 28   GBVxEpQr8R8      17.13.11
# ...

# %%
row_concat.shape
# Out:
# (399, 17)

# %%
CA.shape
# Out:
# (199, 17)

# %%
US.shape
# Out:
# (200, 17)

# %%
sort_row_concat=row_concat.sort_values(by="views",ascending=False)

# %%
sort_row_concat.head()
#US,CA 둘 다 Ed Sheeran,Eminem의 똑같은 노래가 가장 높은 조회수를 보였다
# Out:
#        video_id trending_date  \
# 35  2Vv-BfVoq4g      17.13.11
# 1   2Vv-BfVoq4g      17.13.11
# 0   n1WpP7iowLc      17.13.11
# 14  n1WpP7iowLc      17.13.11
# 33  c64I9HNpiOY      17.13.11
#
#                                                 title channel_title  \
# 35        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
# 1         Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
# 0          Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 14         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 33  Padmavati : Ek Dil Ek Jaan Video Song | Deepik...      T-Series
#
#     category_id              publish_time  \
# 35           10  2017-11-09T11:04:14.000Z
# 1            10  2017-11-09T11:04:14.000Z
# 0            10  2017-11-10T17:00:03.000Z
# 14           10  2017-11-10T17:00:03.000Z
# 33           10  2017-11-11T06:14:19.000Z
#
#                                                  tags     views    likes  \
# ...

# %%
avg_views_by_category_id = row_concat.groupby('category_id').views.mean() 
print(avg_views_by_category_id)
print(avg_views_by_category_id.sort_values(ascending=False))
# Out:
# category_id
# 1     8.914633e+05
# 2     2.049266e+05
# 10    2.762740e+06
# 15    1.962350e+05
# 17    6.328691e+05
# 19    1.626020e+05
# 20    4.610087e+05
# 22    6.894806e+05
# 23    1.397369e+06
# 24    6.963630e+05
# 25    2.703127e+05
# 26    1.073739e+06
# 27    2.916131e+05
# 28    6.962979e+05
# 29    2.971520e+05
# 43    6.885310e+05
# Name: views, dtype: float64
# category_id
# 10    2.762740e+06
# 23    1.397369e+06
# 26    1.073739e+06
# 1     8.914633e+05
# 24    6.963630e+05
# 28    6.962979e+05
# 22    6.894806e+05
# 43    6.885310e+05
# 17    6.328691e+05
# 20    4.610087e+05
# 29    2.971520e+05
# 27    2.916131e+05
# 25    2.703127e+05
# 2     2.049266e+05
# 15    1.962350e+05
# 19    1.626020e+05
# Name: views, dtype: float64
